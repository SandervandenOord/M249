# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
sns.set(font_scale=2, style='white')

# %%
data = {'a':[5,6,4,5,6,3,4], 'b':[1,3,0,2,3,2,1]}

# %%
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#    a  b
# 0  5  1
# 1  6  3
# 2  4  0

# %%
df.mean().plot(kind='bar', title='average of a and b')
sns.despine();
